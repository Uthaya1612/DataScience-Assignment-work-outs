# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?

# %% [markdown]
# First we need to install Bokeh library using python.Then install input and output module and plotting module inaddition install io.output_notebook() to diplay the output.

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.

# %% [markdown]
# Any plot is usually made up of one or many geometrical shapes such as line, circle, rectangle, etc. These shapes have visual information about the corresponding set of data. In Bokeh terminology, these geometrical shapes are called gylphs

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
from bokeh.plotting import figure, output_file, show
fig = figure()
output_file('scatter.html')
fig.scatter([1, 4, 3, 2, 5], [6, 5, 2, 4, 7], marker = "circle", size = 20, fill_color = "grey")
show(fig)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1477">Loading BokehJS ...</span>
#     </div>
#   <div id="a38b3e5e-5cdb-4984-8cfc-590122d69b7e" data-root-id="p1478" style="display: contents;"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
fig.scatter([1, 4, 3, 2, 5], [6, 5, 2, 4, 7], marker = "square", size = 5, fill_color = "purple",legend_label= "L1")
fig.title = "X vs Y"
fig.xaxis.axis_label = "X axis"
fig.yaxis.axis_label = "Y axis"
show(fig)
# Out:
#   <div id="695d7e19-881c-4968-a325-7ecac97d9cb5" data-root-id="p1478" style="display: contents;"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?

# %% [markdown]
# Bokeh server makes it easy to create interactive web applications that connect front-end UI events to running Python code.
#
# Bokeh creates high-level Python models, such as plots, ranges, axes, and glyphs, and then converts these objects to JSON to pass them to its client library, BokehJS.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?

# %% [markdown]
# Bokeh server applications can connect Bokeh plots and widgets to a live running Python process, so that events like UI interactions, making selections, or widget manipulations can trigger real Python code
#
# To embed a basic Bokeh application in a page template, the most common method is to use server_document:
#
# from bokeh.embed import server_document
# script = server_document("https://demo.bokeh.org/slider")
