# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular data visualization library in Python.
# It is a powerful and flexible library that provides a wide range of visualization options.
# We can able to plot different graphs such as
# Line Plot
# Scatter Plot
# Histogram
# Bar plot
# Box plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Scatter plot is graph that plot a relationship point with x and y coordinates.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("X-Y plot")
# Out:
# Text(0.5, 1.0, 'X-Y plot')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# subplot() function adds subplot to a current figure at the specified grid position

# %%
import numpy as np 
#For line 1: 
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500]) 
#For line 2: 
x2 = np.array([0, 1, 2, 3, 4, 5])
y2= np.array([50, 20, 40, 20, 60, 70]) 
#For line 3: 
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60]) 
#For line 4: 
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot()
plt.plot(x1, y1, marker="x", color="green")
plt.subplot()
plt.plot(x2, y2, marker="o", color="blue")
plt.subplot()
plt.plot(x3, y3, marker="*", color="red")
plt.subplot()
plt.plot(x4, y4, marker="o", color="orange")

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
plt.title("Giant companies")
plt.xlabel("Company")
plt.ylabel("Numbers")
# Out:
# Text(0, 0.5, 'Numbers')

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Box plots are used to show distributions of numeric data values, especially when you want to compare them between multiple groups

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = (box1,box2)
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fde92ce2590>,
#   <matplotlib.lines.Line2D at 0x7fde92ce2830>,
#   <matplotlib.lines.Line2D at 0x7fde92ce37f0>,
#   <matplotlib.lines.Line2D at 0x7fde92ce3a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fde92ce2ad0>,
#   <matplotlib.lines.Line2D at 0x7fde92ce2d70>,
#   <matplotlib.lines.Line2D at 0x7fde92ce3d30>,
#   <matplotlib.lines.Line2D at 0x7fde92ce3fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fde92ce22f0>,
#   <matplotlib.lines.Line2D at 0x7fde92ce3550>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fde92ce3010>,
#   <matplotlib.lines.Line2D at 0x7fde92b282b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7